# %%
import requests
import json

# %%
s=requests.Session()

json.loads(s.get("http://codeforces.com/api/user.status?handle=toxic_hack&from=1&count=100000").text)
# Out:
# {'result': [{'author': {'contestId': 355,
#     'ghost': False,
#     'members': [{'handle': 'toxic_hack'}],
#     'participantType': 'PRACTICE',
#     'startTimeSeconds': 1381678200},
#    'contestId': 355,
#    'creationTimeSeconds': 1542312472,
#    'id': 45781220,
#    'memoryConsumedBytes': 24064000,
#    'passedTestCount': 43,
#    'problem': {'contestId': 355,
#     'index': 'E',
#     'name': 'Vasya and Beautiful Arrays',
#     'points': 2500.0,
#     'tags': ['binary search', 'brute force', 'data structures'],
#     'type': 'PROGRAMMING'},
#    'programmingLanguage': 'GNU C++14',
#    'relativeTimeSeconds': 2147483647,
#    'testset': 'TESTS',
#    'timeConsumedMillis': 233,
#    'verdict': 'OK'},
#   {'author': {'contestId': 1062,
#     'ghost': False,
#     'members': [{'handle': 'toxic_hack'}],
#     'participantType': 'PRACTICE',
#     'startTimeSeconds': 1542209700},
#    'contestId': 1062,
#    'creationTimeSeconds': 1542310537,
#    'id': 45780160,
# ...
