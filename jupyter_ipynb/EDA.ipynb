# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
data = pd.read_csv('../data/final.csv')

# %%
data.describe()
# Out:
#        contribution  contest_count       rating   max_rating  friends_count  \
# count   6441.000000    6441.000000  6441.000000  6441.000000    6441.000000
# mean       0.648968      20.576619  1440.101848  1556.414687      28.782487
# std        5.745607      20.917052   232.426607   182.517250      70.549313
# min      -43.000000       1.000000   603.000000  1366.000000       0.000000
# 25%        0.000000       5.000000  1287.000000  1413.000000       4.000000
# 50%        0.000000      14.000000  1414.000000  1488.000000      11.000000
# 75%        0.000000      28.000000  1581.000000  1659.000000      29.000000
# max      151.000000     163.000000  2500.000000  2578.000000    1657.000000
#
#            duration  problem_count  avg_difficulty  avg_difficulty20  \
# count   6441.000000    6441.000000     6441.000000       6441.000000
# mean    1073.935569     127.123428     1206.016621       1629.946308
# std      657.743632     154.928163      167.440872        282.403082
# min       15.000000       1.000000      500.000000        500.000000
# 25%      547.000000      25.000000     1092.592593       1443.589744
# 50%     1004.000000      71.000000     1192.391304       1607.407407
# 75%     1547.000000     171.000000     1301.111111       1794.444444
# max    17853.000000    1611.000000     2013.186813       2716.666667
#
#             median         ...           difficulty_bucket3  \
# count  6441.000000         ...                  6441.000000
# mean   1181.183046         ...                    18.191430
# std     177.788077         ...                    24.797218
# min     500.000000         ...                     0.000000
# 25%    1100.000000         ...                     2.000000
# 50%    1200.000000         ...                     8.000000
# 75%    1300.000000         ...                    26.000000
# max    2000.000000         ...                   233.000000
#
#        difficulty_bucket4  difficulty_bucket5  difficulty_bucket6  \
# count         6441.000000         6441.000000         6441.000000
# mean            15.219531            7.868964            4.616053
# std             24.712344           16.140394           13.114247
# min              0.000000            0.000000            0.000000
# 25%              1.000000            0.000000            0.000000
# 50%              5.000000            2.000000            0.000000
# 75%             19.000000            7.000000            3.000000
# max            300.000000          232.000000          201.000000
#
#        difficulty_bucket7  difficulty_bucket8  difficulty_bucket9  \
# count         6441.000000         6441.000000         6441.000000
# mean             2.162552            1.292656            0.574755
# std              7.917106            5.984573            2.908497
# min              0.000000            0.000000            0.000000
# 25%              0.000000            0.000000            0.000000
# 50%              0.000000            0.000000            0.000000
# 75%              1.000000            0.000000            0.000000
# max            162.000000          132.000000           81.000000
#
#        difficulty_bucket10  difficulty_bucket11  difficulty_bucket12
# count          6441.000000               6441.0          6441.000000
# mean              0.152150                  0.0             0.022667
# std               1.113085                  0.0             0.259805
# min               0.000000                  0.0             0.000000
# 25%               0.000000                  0.0             0.000000
# 50%               0.000000                  0.0             0.000000
# 75%               0.000000                  0.0             0.000000
# max              26.000000                  0.0             8.000000
#
# [8 rows x 52 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6441 entries, 0 to 6440
# Data columns (total 56 columns):
# country                         6441 non-null object
# handle                          6441 non-null object
# contribution                    6441 non-null int64
# contest_count                   6441 non-null int64
# organization                    6441 non-null object
# rating                          6441 non-null int64
# max_rating                      6441 non-null int64
# friends_count                   6441 non-null int64
# rank                            6441 non-null object
# duration                        6441 non-null int64
# problem_count                   6441 non-null int64
# avg_difficulty                  6441 non-null float64
# avg_difficulty20                6441 non-null float64
# median                          6441 non-null int64
# tag_constructive algorithms     6441 non-null int64
# tag_brute force                 6441 non-null int64
# tag_bitmasks                    6441 non-null int64
# tag_number theory               6441 non-null int64
# tag_shortest paths              6441 non-null int64
# tag_matrices                    6441 non-null int64
# tag_games                       6441 non-null int64
# tag_greedy                      6441 non-null int64
# tag_two pointers                6441 non-null int64
# tag_probabilities               6441 non-null int64
# tag_Other                       6441 non-null int64
# tag_sortings                    6441 non-null int64
# tag_dp                          6441 non-null int64
# tag_string suffix structures    6441 non-null int64
# tag_graph matchings             6441 non-null int64
# tag_math                        6441 non-null int64
# tag_dsu                         6441 non-null int64
# tag_hashing                     6441 non-null int64
# tag_combinatorics               6441 non-null int64
# tag_geometry                    6441 non-null int64
# tag_graphs                      6441 non-null int64
# tag_trees                       6441 non-null int64
# tag_data structures             6441 non-null int64
# tag_divide and conquer          6441 non-null int64
# tag_implementation              6441 non-null int64
# tag_binary search               6441 non-null int64
# tag_dfs and similar             6441 non-null int64
# tag_strings                     6441 non-null int64
# tag_ternary search              6441 non-null int64
# difficulty_bucket0              6441 non-null int64
# difficulty_bucket1              6441 non-null int64
# difficulty_bucket2              6441 non-null int64
# difficulty_bucket3              6441 non-null int64
# difficulty_bucket4              6441 non-null int64
# difficulty_bucket5              6441 non-null int64
# difficulty_bucket6              6441 non-null int64
# difficulty_bucket7              6441 non-null int64
# difficulty_bucket8              6441 non-null int64
# difficulty_bucket9              6441 non-null int64
# difficulty_bucket10             6441 non-null int64
# difficulty_bucket11             6441 non-null int64
# difficulty_bucket12             6441 non-null int64
# dtypes: float64(2), int64(50), object(4)
# memory usage: 2.8+ MB

# %%
data.head()
# Out:
#   country           handle  contribution  contest_count organization  rating  \
# 0   India     Sumeet.Varma             1             46      DA-IICT    2500
# 1   India  akshay_miterani             1             72      DA-IICT    2052
# 2   India     kuldeeppatel             0             37      DA-IICT    2030
# 3   India        tanmay273             0             90      DA-IICT    2006
# 4   India    Hiren.Vaghela             0             32      DA-IICT    1997
#
#    max_rating  friends_count              rank  duration         ...           \
# 0        2515           1657       grandmaster      1416         ...
# 1        2052            390  candidate master      1291         ...
# 2        2030            208  candidate master      1577         ...
# 3        2006            290  candidate master      1539         ...
# 4        1997            170  candidate master       543         ...
#
#    difficulty_bucket3  difficulty_bucket4  difficulty_bucket5  \
# 0                  89                 106                 113
# 1                  96                  79                  34
# 2                  37                  26                  18
# 3                 114                 128                  86
# 4                  92                 117                  89
#
#    difficulty_bucket6  difficulty_bucket7  difficulty_bucket8  \
# 0                  82                  63                  45
# 1                  15                  14                   4
# 2                   6                   4                   1
# 3                  65                  49                  21
# 4                  70                  34                  24
#
#    difficulty_bucket9  difficulty_bucket10  difficulty_bucket11  \
# 0                  13                   10                    0
# 1                   3                    1                    0
# 2                   0                    0                    0
# 3                   7                    1                    0
# 4                  11                    2                    0
#
#    difficulty_bucket12
# 0                    0
# 1                    0
# 2                    0
# 3                    1
# 4                    0
#
# [5 rows x 56 columns]

# %%
ax = data.plot.scatter(x='problem_count', y='max_rating', color='red', label='Problems')
data.plot.scatter(x='problem_count', y='rating', color='green', label='Problems')

ax.set_title("Scatter plot between problem_count and max_rating")
plt.show()

# %%
ax = data.plot.scatter(x='contest_count', y='max_rating', color='red', label='Contests')
data.plot.scatter(x='contest_count', y='rating', color='green', label='Contests')

ax.set_title("Scatter plot between contest_count and max_rating")
plt.show()

# %%
ax = data.plot.scatter(x='friends_count', y='max_rating', color='red', label='Contests')
data.plot.scatter(x='friends_count', y='rating', color='green', label='Contests')

ax.set_title("Scatter plot between friends_count and max_rating")
plt.show()

# %%
# %matplotlib inline 

data[["avg_difficulty","contest_count","max_rating"]].hist(bins=40, figsize=(20,15))
plt.show()

# %%
def top10(x):
    a = sorted(list(x),reverse=True)
    n=int(max(len(a)*0.1,1))
    return sum(a[:n])/n
    
data.pivot_table(values='max_rating', index='organization', 
                 aggfunc=top10).sort_values(by=['max_rating'], ascending=False, inplace=False)
# Out:
#                                                 max_rating
# organization
# Indian Institute of Technology Madras          2234.000000
# IIT Kanpur                                     2148.461538
# SSN College Of Engineering                     2117.500000
# IIT Delhi                                      2112.916667
# IIT Roorkee                                    2094.695652
# BITS, Pilani                                   2088.100000
# IIIT Delhi                                     2080.000000
# Indian Institute of Technology Kharagpur       2075.142857
# IIT Bombay                                     2070.272727
# IIIT Hyderabad                                 2066.540541
# IIT Indore                                     2048.111111
# Microsoft                                      2033.500000
# NITK , Surathkal                               2032.750000
# IIT BHU Varanasi                               2024.923077
# Delhi Technological University                 2014.333333
# SVNIT                                          2012.666667
# DA-IICT                                        2012.052632
# IIT Patna                                      1996.000000
# IIT Kharagpur                                  1990.454545
# IIT Jodhpur                                    1984.250000
# IIT Hyderabad                                  1979.600000
# MNNIT, Allahabad                               1977.200000
# IIT Guwahati                                   1970.428571
# BITS Pilani Goa Campus                         1960.500000
# Indian Institute of Technology Delhi           1959.000000
# NIT Warangal                                   1957.000000
# BIT, Mesra                                     1945.600000
# IIIT Allahabad                                 1932.406250
# IIIT Bangalore                                 1921.800000
# NIT Kurukshetra                                1918.000000
# ...                                                    ...
# IIEST, Shibpur                                 1769.333333
# IIT BHU, Varanasi                              1767.600000
# Army Institute Of Technology (AIT), Pune       1767.000000
# MANIT Bhopal                                   1767.000000
# ABV-IIITM Gwalior                              1761.833333
# Pune Institute of Computer Technology          1760.833333
# BIT Mesra, Ranchi                              1758.500000
# BIT Mesra                                      1755.500000
# Madras institute of technology                 1750.500000
# BITS Pilani, Pilani campus                     1744.500000
# Dwarkadas J. Sanghvi College of Engineering    1740.500000
# IIT(ISM) DHANBAD                               1739.000000
# Lovely Professional University                 1736.600000
# BIRLA INSTITUTE OF TECHNOLOGY,  MESRA          1732.500000
# College of Engineering, Guindy                 1732.000000
# NIT Jamshedpur                                 1731.444444
# Jamia Millia Islamia                           1730.500000
# NIT Silchar                                    1728.400000
# Jalpaiguri Government Engineering College      1725.000000
# BITS Pilani                                    1720.000000
# Thapar University                              1716.000000
# IEM Kolkata                                    1710.000000
# HBTI Kanpur                                    1698.000000
# IIIT - Delhi                                   1696.333333
# Heritage Institute Of Technology               1689.000000
# MNNIT ,Allahabad                               1667.000000
# IIIT - HYDERABAD                               1651.666667
# Kamla Nehru Institute Of Technology            1648.000000
# Motilal Nehru National Institue of Technology  1622.500000
# SRM University                                 1609.500000
#
# [83 rows x 1 columns]

# %%
ax = data[data.contribution>5].plot.scatter(x='contribution', y='max_rating', color='red', label='Contrubutions')
data[data.contribution>5].plot.scatter(x='contribution', y='rating', color='green', label='Contrubutions')

ax.set_title("Scatter plot between Contrubutions and max_rating")
plt.show()

# %%
ax = data[data.duration<4000].plot.scatter(x='duration', y='max_rating', color='red', label='Contests')
data[data.duration<4000].plot.scatter(x='duration', y='rating', color='green', label='Contests')

ax.set_title("Scatter plot between friends_count and max_rating")
plt.show()

# %%
# Problem tags

tags = ['implementation', 'greedy', 'math', 'brute force', 'dp', 'constructive algorithms', 'data structures',
        'sortings', 'dfs and similar', 'binary search', 'graphs', 'number theory', 
        'strings', 'trees', 'combinatorics', 'two pointers', 'bitmasks', 'dsu', 'geometry', 'shortest paths', 'probabilities', 'hashing', 'games', 'string suffix structures', 'divide and conquer', 'graph matchings', 'ternary search', 'matrices', 'Other']

# %%
tags=list(map(lambda x:'tag_'+x,tags))

# %%
corr_matrix = data.corr() # corr() : Pandas method, computes pairwise correlation of columns, excluding NA/null values
corr_matrix["max_rating"].sort_values(ascending=False)
# Out:
# max_rating                      1.000000
# rating                          0.879823
# avg_difficulty                  0.747098
# avg_difficulty20                0.728267
# median                          0.707273
# difficulty_bucket5              0.656712
# tag_combinatorics               0.645798
# difficulty_bucket4              0.635172
# tag_bitmasks                    0.629713
# tag_data structures             0.627873
# difficulty_bucket6              0.625149
# contest_count                   0.623306
# tag_dp                          0.622195
# tag_dfs and similar             0.619896
# tag_trees                       0.618779
# friends_count                   0.615253
# tag_graphs                      0.612605
# tag_dsu                         0.611566
# tag_binary search               0.609404
# tag_probabilities               0.604577
# tag_constructive algorithms     0.600693
# tag_Other                       0.591252
# tag_geometry                    0.590065
# tag_two pointers                0.581857
# tag_divide and conquer          0.581493
# tag_greedy                      0.573572
# problem_count                   0.573467
# tag_hashing                     0.568989
# difficulty_bucket7              0.568747
# tag_games                       0.565887
# tag_brute force                 0.564271
# tag_number theory               0.563413
# tag_math                        0.557617
# difficulty_bucket3              0.556702
# tag_shortest paths              0.552044
# tag_sortings                    0.542213
# tag_matrices                    0.536098
# tag_ternary search              0.513635
# difficulty_bucket8              0.504940
# difficulty_bucket2              0.484753
# tag_implementation              0.479860
# tag_string suffix structures    0.477215
# difficulty_bucket9              0.451814
# tag_strings                     0.431361
# difficulty_bucket10             0.373331
# difficulty_bucket1              0.356055
# contribution                    0.294820
# duration                        0.288176
# tag_graph matchings             0.250974
# difficulty_bucket0              0.228217
# difficulty_bucket12             0.219324
# difficulty_bucket11                  NaN
# Name: max_rating, dtype: float64

# %%
data[tags]

labels = tags
sizes = data[tags].sum()

fig1, ax1 = plt.subplots(figsize=(11, 7))
fig1.subplots_adjust(0.3,0,1,1)


theme = plt.get_cmap('YlOrRd')
ax1.set_prop_cycle("color", [theme(1. * i / len(sizes)) for i in range(len(sizes)-1,-1,-1)])

_, _ = ax1.pie(sizes, startangle=90)

ax1.axis('equal')

total = sum(sizes)
plt.legend(
    loc='upper left',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100) for l, s in zip(labels, sizes)],
    prop={'size': 11},
    bbox_to_anchor=(0.0, 1),
    bbox_transform=fig1.transFigure
)

plt.show()
